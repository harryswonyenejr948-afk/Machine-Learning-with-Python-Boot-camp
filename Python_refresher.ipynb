# %% [markdown]
# <a href="https://colab.research.google.com/github/harryswonyenejr948-afk/Machine-Learning-with-Python-Boot-camp/blob/main/Python_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# crate a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80

# Pull the value out of the basket
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Variables (ML Anchor)

# %%
#--- THE CLUES (Features grouped as X) ---
rainfall_mm = 45.2   # Clue 1
bags_available = 100 # Clue 2

# --- THE GOAL (Target labeled as y) ---
predicted_price = 3200  # What our AI calculates

print("Inputs (X):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (X): 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding Print statements

# %%
Liberia= 1847
print(Liberia)
print("Liberia")
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Variables

# %%
plum=50
print("plum previous price was:",plum)
plum=80
print("plum new price is:",plum)
# Out:
# plum previous price was: 50
# plum new price is: 80

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quantity)) #
print(type(price)) #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
