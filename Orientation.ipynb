# %% [markdown]
# <a href="https://colab.research.google.com/github/harryswonyenejr948-afk/Machine-Learning-with-Python-Boot-camp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of Addition

# %%
A=2
B=3
C=2+3
print(C)
# Out:
# 5

# %% [markdown]
# Example of a String

# %%
Greetings= "Advice na, pror"
print(Greetings)
# Out:
# Advice na, pror
