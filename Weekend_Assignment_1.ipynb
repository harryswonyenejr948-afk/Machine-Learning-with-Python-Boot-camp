# %% [markdown]
# <a href="https://colab.research.google.com/github/harryswonyenejr948-afk/Machine-Learning-with-Python-Boot-camp/blob/main/Weekend_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python
#
# **Part 1 : Understanding print() variable vs. Quoted Text**

# %%
# Student: Harry S Wonyene Jr
# Date: May 25, 2026

# Problem 1
Liberia = 1847

print(Liberia)  # Prints the value stored in the variable Liberia
print("Liberia")  # Prints the word Liberia because it is inside quotes
# Out:
# 1847
# Liberia

# %%
# Problem 2
Country = Liberia
print("Liberia became independent in , 1847")
# Out:
# Liberia became independent in , 1847

# %%
# Problem 3
print('The year is "1847"')
# Out:
# The year is "1847"

# %% [markdown]
# # **Part 2: Creating variables with Different Data** **Types**

# %%
# Problem 4
market_name = "Gobachop Market"
total_market_table =150
price_per_bag = 3200.50
is_market_open = True

print("Market name:", market_name)
print("Total market tables:", total_market_table)
print("Price per bag:", price_per_bag)
print("Is market open:", is_market_open)

# Bonus
print(type(market_name))
print(type(total_market_table))
print(type(price_per_bag))
print(type(is_market_open))
# Out:
# Market name: Gobachop Market
# Total market tables: 150
# Price per bag: 3200.5
# Is market open: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Problem 5
current_price = 2250.75
quantity = 10

total_cost = current_price * quantity

print("Total cost for 10 bags:", total_cost, "LRD")
# Out:
# Total cost for 10 bags: 22507.5 LRD

# %%
# problem 6
has_scarcity = False
is_rainy = True
print("scarcity today:", has_scarcity)
print("Rainy today:", is_rainy)
# Out:
# scarcity today: False
# Rainy today: True

# %% [markdown]
# **Part 3: Arithmetic with variable Market Scenarios**

# %%
# problem 7 - Total Revenue
price_per_bag = 800
quantity = 25
total_revenue= price_per_bag* quantity
print("price per bag of potatoes is:", price_per_bag ,)
print("The Coustomer buys", quantity, "of potatoes")
print("Total revenue:" ,total_revenue)
# Out:
# price per bag of potatoes is: 800
# The Coustomer buys 25 of potatoes
# Total revenue: 20000

# %%
# Problem 8 - Price Increase
today_price = 3200
increase = 150

tomorrow_price = today_price + increase
print("Tomorrow's price:", tomorrow_price)
# Out:
# Tomorrow's price: 3350

# %%
# Problem 9 - Splitting Cost
Onion_cost = 1800
trader = 3
cost_per_trader = 1800 / 3
print("Total cost of onion:", Vita_cost , "LRD")
print("Number of traders:", trader)

print("Cost per trader:",cost_per_trader, "LRD")
# Out:
# Total cost of onion: 1800 LRD
# Number of traders: 3
# Cost per trader: 600.0 LRD

# %%
#  problem 10 - Discount on a Gallon of Oil
palm_oil_price = 250.0
discount_percent = 0.10

discount_value = palm_oil_price * discount_percent
new_price = palm_oil_price - discount_value

print("Discount amount:", discount_value, "LRD")
print("Final price:", new_price, "LRD")
# Out:
# Discount amount: 25.0 LRD
# Final price: 225.0 LRD

# %% [markdown]
# **Part 4: Mixing Variable and Prints**

# %%
# Problem 11 - Variable Names VS Quoted Strings
item = "cassava"
price = 800

print(item)
print("item")
print(price)
print("price")

# print(item) prints the value stored in item.
# print("item") prints the exact word item because it is in quotes.
# Out:
# cassava
# item
# 800
# price

# %%
# Problem 12 - Using Variable Inside Message
product = "pepper"
cost = 150.50

print("one bag of", product, "costs", cost, "LRD")

# Bonus Problem
Liberia = 1847

print("Liberia became independent in", Liberia)
print('Liberia is "1847 years old!"')
# Out:
# one bag of pepper costs 150.5 LRD
# Liberia became independent in 1847
# Liberia is "1847 years old!"

# %% [markdown]
# Weekend Assignment #2.pynb

# %% [markdown]
# Python
#
# Question 1: Type Conversion

# %%
# A

transport_cost = "750"

transport_cost = int(transport_cost)

total_delivery_cost = transport_cost + 250

print("Total delivery cost:", total_delivery_cost)

# Explanation
# int() changes the text "750" into a number so it can be added to 250.
# Out:
# Total delivery cost: 1000

# %%
# B

print(f"Ma Christiana, your final shipping cost is:{total_delivery_cost} LRD.")

# Explanation
# The f-string puts the value of total_delivery_cost inside the sentence.
# Out:
# Ma Christiana, your final shipping cost is:1000 LRD.

# %% [markdown]
# Question 2: Lists & Matrices

# %%
A machine learning model likes data in rows and columns, not in one simple
list.

# %%
# B

loose_stock = [45, 12, 88]

shipping_crate = [[45, 12, 88]]

# Explanation
# The double brackets make the list become a 2D matrix.

# %% [markdown]
# Question 3: Dictionaries

# %%
# A

yield_model_configs = {
    "engine_type": "Decision Tree",
    "max_depth_layers": 15,
    "strict_mode": True
}

# Explanation

# The dictionary stores data using keys and values.

# %%
# B

print(f"""system check: Tuning engine depth to
{yield_model_configs['max_depth_layers']} branches.""")

# Explanation
# The code get the value from dictionary and prints its in the message.
# Out:
# system check: Tuning engine depth to
# 15 branches.

# %% [markdown]
# Question 4: Method VS Attributes

# %%
import pandas as pd

# A

# Assuming gobachop_data is meant to be a DataFrame
gobachop_data = pd.DataFrame(shipping_crate)

print(gobachop_data.shape)

# Explanation
# .shape shows the number of rows and columns in the table.
# Out:
# (1, 3)

# %%
# B

gobachop_data.head(1)

# Explanation
# .head(1) show only the first row of the table.
# Out:
#     0   1   2
# 0  45  12  88
